# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd;
import numpy as np;
import os;
import time;
import datetime;
import warnings;
warnings.filterwarnings('ignore');

# %% [markdown]
# # OC WEEKLY TRACKER TOOTHPASTE

# %%
#Reading TP raw files
TP_Weekly= pd.read_excel("//falmumapp34/Nielsen Connect Transition & Maintenance (20-SCP-3650)/03. Raw Data/Connect Data/OW Weekly Reports/OC Weekly Report TP.xlsx")

# %%
#Replacing NaN values with 0
TP_Weekly.fillna(value=0,inplace=True)

# %% [markdown]
# **Creating Fact, Market and Product Mapping Dictionaries to change corresponding names as required going ahead**

# %%
Fact_Mapping = {
    "$":"Dollars",
    "$ Shr - CP CATEGORY":"$ Share",
    "$ Shr Chg YA - CP CATEGORY":"$ Share YAG Chg",
    "$ Chg YA":"Dollars YAG Chg",
    "$ % Chg YA":"Dollars YAG %Chg",
    "Base $ Shr Chg YA - $ - CP CATEGORY":"Baseline Chg",
    "Incr $ Shr Chg YA - $ - CP CATEGORY":"Incr Chg",
    "% $ Base Chg YA":"Baseline $ % Chg",
    "% EQ Base Chg YA":"Baseline Vol % Chg",
    "Base EQ Price % Chg YA":"Baseline RASP % Chg",
    "Avg # of Items Chg YA":"Avg # of Items YAG Chg",
    "Base EQ / TDP":"Vol Velocity",
    "Base EQ / TDP Chg YA":"Vol Velocity YAG Chg",
    "Any Promo Unit Price % Chg YA":"Promo RASP % Chg",
    "Any Feat %ACV":"Feature % ACV",
    "Any Disp %ACV":"Display % ACV",
    "Any Price Decr %ACV":"TPR % ACV",
    "Any Promo %ACV":"Any Promo % ACV",
    "Base $ Shr - $ - CP CATEGORY":"Baseline $ Share",
    "Incr $ Shr - $ - CP CATEGORY":"Incr $ Share",
    "Any Promo $ Shr - CP CATEGORY":"Promo $ Share",
    "Base $":"BASELINE DOLLARS",
    "Incr $":"INCR DOLLARS",
    "Any Price Decr %ACV Chg YA":"TPR % ACV Chg",
    "Any Feat %ACV Chg YA":"Feature % ACV Chg",
    "Any Disp %ACV Chg YA":"Display % ACV Chg",
    "Units":"Units",
    "Units Chg YA":"Units YAG Chg",
    "Units % Chg YA":"Units YAG %Chg",
    "EQ Chg YA":"Vol YAG Chg",
    "EQ % Chg YA":"Vol YAG %Chg",
    "Any Promo $ Shr - CP CATEGORY":"Promo $ Share",
    "Any Feat $ Shr - CP CATEGORY":"Feature $ Share",
    "Disp w/o Feat $ Shr - CP CATEGORY":"Display $ Share",
    "Avg # of Items":"Avg # of Items",
    "%ACV":"% ACV",
    "EQ Shr Chg YA - CP CATEGORY":"Vol Share YAG Chg",
    "EQ Shr - CP CATEGORY":"Vol Share",
    "Avg Unit Price":"RASP",
    "Base Unit Price":"Baseline RASP",
    "Any Promo Unit Price":"Promo RASP",
    "Units Shr - CP CATEGORY":"Unit Share",
    "Units Shr Chg YA - CP CATEGORY":"Unit Share YAG Chg",
    "$ YA":"DOLLARS YAG",
    "EQ":"Vol",
    "EQ YA":"Vol YAG"
    }

# %%
Market_Mapping={
    "ALL OUTLET":"ALL OUTLET",
    "Walmart Total US TA":"     WALMART",
    "Target Total BM/FF TA":"     TARGET",
    "Kmart Total TA":"     KMART",
    "DRUG":"DRUG",
    "CVS Total Corp WO HI TA":"     CVS",
    "Duane Reade Total TA":"     DUANE READE",
    "Rite Aid - Corp Total TA":"     RITE AID",
    "Walgreens Total TA":"     WALGREENS",
    "VDC":"VDC",
    "BJs Total TA":"     BJ'S",
    "Dol Gen Total TA":"     DOLLAR GENERAL",
    "Family Dollar Total TA":"     FAMILY DOLLAR",
    "Sam's Total TA":"     SAM'S",
    "CLUB":"CLUB",
    "ALBSCO Total Company TA":"     ALBERTSONS/SAFEWAY",
    "Ahold USA Corp Total TA":"     AHOLD",
    "Fiesta Total TA":"     FIESTA",
    "Food Lion Total TA":"     FOOD LION",
    "Giant Eagle Total TA":"     GIANT EAGLE",
    "Meijer Total TA":"     MEIJER",
    "Price Chopper Total TA":"     PRICE CHOPPER",
    "Publix Total TA":"     PUBLIX",
    "ShopRite Total TA":"     SHOPRITE",
    "Wegmans Total TA":"     WEGMAN'S",
    "FOOD":"FOOD",
    "MASS":"MASS"
    }

# %%
Product_Mapping = {
    "TOOTHPASTE":"TOOTHPASTE",
    "TOOTHPASTE | COLGATE-PALMOLIVE":"CP",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE":"COLGATE",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE BASE":"     COLGATE BASE",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE RENEWAL":"     COLGATE RENEWAL",
    "TOOTHPASTE | COLGATE-PALMOLIVE | TOMS":"TOMS",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE TOTAL":"     COLGATE TOTAL",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE MAX FRANCHISE":"     COLGATE MAX FRESH",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE OPTIC WHITE":"     COLGATE OPTIC WHITE",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE ESSENTIALS":"     COLGATE ESSENTIALS",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE ZERO":"     COLGATE ZERO",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE SENS":"     COLGATE SENS",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE ENAMEL HEALTH":"     COLGATE ENAMEL HEALTH",
    "TOOTHPASTE | COLGATE-PALMOLIVE | COLGATE | COLGATE FOR KIDS":"     COLGATE KIDS",
    "TOOTHPASTE | P&G":"P&G",
    "TOOTHPASTE | P&G | CREST":"CREST",
    "TOOTHPASTE | P&G | CREST | CREST BASE":"     CREST BASE",
    "TOOTHPASTE | P&G | CREST | CREST COMPLETE":"     CREST COMPLETE",
    "TOOTHPASTE | P&G | CREST | CREST PRO-HLTH":"     CREST PRO HEALTH",
    "TOOTHPASTE | P&G | CREST | CREST 3D WHITE":"     CREST 3D",
    "TOOTHPASTE | CREST PRO-HEALTH GUM DETOXIFY":"     CREST DETOXIFY",
    "TOOTHPASTE | P&G | CREST | CREST GUM & ENAMEL REPAIR":"     CREST GUM & ENAMEL",
    "TOOTHPASTE | P&G | NATIVE":"NATIVE",
    "TOOTHPASTE | GSK":"GSK",
    "TOOTHPASTE | GSK | SENSODYNE":"SENSODYNE",
    "TOOTHPASTE | SENSODYNE PRO NAMEL":"     SENSODYNE PRONAMEL",
    "TOOTHPASTE | SENSODYNE REPAIR AND PROTECT":"     SENSODYNE R&P",
    "TOOTHPASTE | SENSODYNE COMPLETE PROTECTION":"     SENSODYNE COMPLETE",
    "TOOTHPASTE | SENSODYNE TRUE WHITE":"     SENSODYNE TRUE WHITE",
    "TOOTHPASTE | GSK | PARODONTAX":"PARODONTAX",
    "TOOTHPASTE | GSK | AQUAFRESH":"AQUAFRESH",
    "TOOTHPASTE | GSK | BIOTENE":"BIOTENE",
    "TOOTHPASTE | CHURCH & DWIGHT":"CHURCH & DWIGHT",
    "TOOTHPASTE | CHURCH & DWIGHT | A&H":"ARM & HAMMER",
    "TOOTHPASTE | CHURCH & DWIGHT | ORAJEL":"ORAJEL",
    "C&D VALUE":"C&D VALUE",
    "TOOTHPASTE | PRVT LBL":"PRIVATE LABEL",
    "TOOTHPASTE | COLGATE-PALMOLIVE | HELLO":"HELLO",
    "TOOTHPASTE | SCHMIDT'S":"SCHMIDT'S",
    "TOOTHPASTE | MOON":"MOON",
    "TOOTHPASTE | REM MFG | REM BRAND":"ALL OTHER MFG",
    "TOOTHPASTE | SENSODYNE SENSITIVITY & GUM":"     SENSODYNE SENSITIVITY & GUMxxx",
    "TOOTHPASTE | SENSODYNE BASE":"     SENSODYNE BASExxx",
    "SENSODYNE BASE":"     SENSODYNE BASE",
    "SENSODYNE SENSITIVITY & GUM":"     SENSODYNE SENSITIVITY & GUM",
    "TOOTHPASTE | SENSODYNE RAPID RELIEF":"     SENSODYNE RAPID RELIEF",
    "TOOTHPASTE | BURT'S BEES":"BURT'S BEES",
    "TOOTHPASTE | HELLO KIDS":"     HELLO KIDS",
    "TOOTHPASTE | HELLO ADULT":"     HELLO ADULT",
    }

# %% [markdown]
# **Updating Time Period Nomenclature**

# %%
TP_Weekly["Periods"] = TP_Weekly["Periods"].str.replace("1 w/e","W/E")

# %%
#Updating the mappings
TP_Weekly["Markets"].replace(Market_Mapping,inplace=True)
TP_Weekly["Products"].replace(Product_Mapping,inplace=True)
TP_Weekly.rename(columns=Fact_Mapping,inplace=True)

# %%
#Changing column names
mapping = {"Markets":"MKT", "Products":"PROD", "Periods":"PER"}
TP_Weekly.rename(columns = mapping, inplace = True)

# %%
#Sorting the columns
final_column_sorting=['MKT', 'PROD', 'PER', "Dollars","$ Share","$ Share YAG Chg","Dollars YAG Chg","Dollars YAG %Chg","Baseline Chg","Incr Chg","Baseline $ % Chg","Baseline Vol % Chg","Baseline RASP % Chg","Avg # of Items YAG Chg","Vol Velocity","Vol Velocity YAG Chg","Promo RASP % Chg","DOLLARS YAG","Feature % ACV","Display % ACV","TPR % ACV","Any Promo % ACV","Baseline $ Share","Incr $ Share","Promo $ Share","BASELINE DOLLARS","INCR DOLLARS","TPR % ACV Chg","Feature % ACV Chg","Display % ACV Chg","Units","Units YAG Chg","Units YAG %Chg","Vol","Vol YAG Chg","Vol YAG %Chg","Promo $ Share","Feature $ Share","Display $ Share","Avg # of Items","% ACV","Vol Share YAG Chg","Vol Share","Vol YAG","RASP","Baseline RASP","Promo RASP","Unit Share","Unit Share YAG Chg"]
final = TP_Weekly[final_column_sorting]

# %%
path_TP="//falmumapp34/Nielsen Connect Transition & Maintenance (20-SCP-3650)/05. Output Data/"

# %%
#Writing the file to the output folder
final.to_csv(path_TP+"OC_Weekly_Report_TP.csv",index=False)

# %% [markdown]
# # OC WEEKLY TRACKER TOOTHBRUSH

# %% [markdown]
# ## TOOTHBRUSH TY

# %%
#Reading the TB raw file
TB_Weekly= pd.read_excel("//falmumapp34/Nielsen Connect Transition & Maintenance (20-SCP-3650)/03. Raw Data/Connect Data/OW Weekly Reports/OC Weekly Report TB.xlsx")

# %%
#Replacing NaN values with 0
TB_Weekly.fillna(value=0,inplace=True)

# %% [markdown]
# **Creating Fact, Market and Product Mapping Dictionaries to change corresponding names as required going ahead**

# %%
Fact_Mapping = {
    "$":"Dollars",
    "$ % Chg YA":"Dollars YAG %Chg",
    "$ YA":"Dollars YAG",
    "EQ":"EQ Units",
    "EQ YA":"Vol YAG",
    "EQ % Chg YA":"Vol YAG %Chg",
    "Units":"Units",
    "Units YA":"Units YAG Period",
    "Units % Chg YA":"Units YAG %Chg",
    "$ Shr - CP CATEGORY":"MTB $ Share",
    "$ Shr Chg YA - CP CATEGORY":"MTB $ Share YAG Chg",
    #"$ Shr - CP CATEGORY":"PTB $ Share",
    #"$ Shr Chg YA - CP CATEGORY":"PTB $ Share YAG Chg",
    "$ Shr - CP MANUAL AND PWR":"$ Share",
    "$ Shr Chg YA - CP MANUAL AND PWR":"$ Share YAG Chg",
    "EQ Shr - CP MANUAL AND PWR":"Vol Share",
    "EQ Shr Chg YA - CP MANUAL AND PWR":"Vol Share YAG Chg",
    "EQ Shr - CP CATEGORY":"MTB Vol Share",
    "EQ Shr Chg YA - CP CATEGORY":"MTB Vol Share YAG Chg",
    #"EQ Shr - CP CATEGORY":"PTB Vol Share",
    #"EQ Shr Chg YA - CP CATEGORY":"PTB Vol Share YAG Chg",
    "Units Shr - CP MANUAL AND PWR":"Unit Share",
    "Units Shr Chg YA - CP MANUAL AND PWR":"Unit Share YAG Chg",
    "Units Shr - CP CATEGORY":"PTB Unit Share",
    "Units Shr Chg YA - CP CATEGORY":"PTB Unit Share YAG Chg",
    #"Units Shr - CP CATEGORY":"MTB Unit Share",
    #"Units Shr Chg YA - CP CATEGORY":"MTB Unit Share YAG Chg",
    "Avg Unit Price":"RASP",
    "Avg Unit Price % Chg YA":"RASP YAG %Chg",
    "TDP":"Total Distribution Pts",
    "TDP Chg YA":"Total Distribution Pts YAG Chg",
    "Any Promo $":"Promo Dollars",
    "Any Promo $ Shr - CP CATEGORY":"MTB Promo $ Share",
    #"Any Promo $ Shr - CP CATEGORY":"PTB Promo $ Share",
    "Any Promo $ Shr Chg YA - CP CATEGORY":"MTB Promo $ Share YAG Chg",
    #"Any Promo $ Shr Chg YA - CP CATEGORY":"PTB Promo $ Share YAG Chg",
    "Any Promo $ Chg YA":"Dollars w/Any Promo YAG Chg",
    "Any Promo $ YA":"Promo Dollars YAG"
    }

# %%
Market_Mapping = {
    "Total US xAOC":"ALL OUTLET",
    "Total US Food":"FOOD",
    "Total US Drug":"DRUG",
    "MASS":"MASS",
    "Dol Gen Total TA":"DOLLAR GENERAL",
    "Family Dollar Total TA":"FAMILY DOLLAR",
    "BJs Total TA":"BJ'S",
    "Sam's Total TA":"SAM'S",
    "Walmart Total US TA":"WALMART",
    "Target Total BM/FF TA":"TARGET",
    "CVS Total Corp WO HI TA":"CVS",
    "Walgreens Corp Total TA":"WALGREENS",
    "Rite Aid - Corp Total TA":"RITE AID",
    "ShopRite Total TA":"SHOPRITE",
    "Publix Total TA":"PUBLIX",
    "Ahold USA Corp Total TA":"AHOLD",
    "Meijer Total TA":"MEIJER",
    "Wegmans Total TA":"WEGMAN'S",
    "VDC":"VDC",
    "CLUB":"CLUB",
    "ALBSCO Total Company TA":"ALBERTSONS/SAFEWAY"
    }

# %%
Product_Mapping={
    "TB Category":"TB Category",
    "MANUAL+POWER | MANUAL":"MTB Category",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE":"Colgate MTB",
    "MANUAL+POWER | POWER":"PTB Category",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE":"Colgate PTB",
    "MANUAL+POWER | POWER | HYBRID":"Hybrid TB",
    "MANUAL+POWER | POWER | BATTERY":"Battery TB",
    "MANUAL+POWER | POWER | BATTERY | BASE":"Battery Base",
    "MANUAL+POWER | POWER | BATTERY | REFILL":"Battery Refills",
    "MANUAL+POWER | POWER | ELECTRIC":"Electric TB",
    "MANUAL+POWER | POWER | ELECTRIC | BASE":"Electric Base",
    "MANUAL+POWER | POWER | ELECTRIC | REFILL":"Electric Refills",
    "CP TOOTHBRUSHES":"CP TOOTHBRUSHES",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | TOMS OF MAINE":"TOMS MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | HELLO":"HELLO MTB",
    "P&G Toothbrushes":"P&G Toothbrushes",
    "MANUAL+POWER | MANUAL | P&G":"P&G MTB",
    "MANUAL+POWER | POWER | P&G":"P&G PTB",
    "CP MTB":"CP MTB",
    "CP Battery":"Colgate Battery",
    "MANUAL+POWER | POWER | BATTERY | COLGATE-PALMOLIVE | BASE":"Colgate Battery Base",
    "MANUAL+POWER | POWER | BATTERY | COLGATE-PALMOLIVE | REFILL":"Colgate Battery Refill",
    "MANUAL+POWER | POWER | HYBRID | COLGATE-PALMOLIVE | BASE":"Colgate Hybrid",
    "MANUAL+POWER | MANUAL | ORAL-B":"ORAL-B MTB",
    "MANUAL+POWER | POWER | ORAL-B":"ORAL-B PTB",
    "ORAL-B TOOTHBRUSHES":"ORAL-B TOOTHBRUSHES",
    "MANUAL+POWER | POWER | BATTERY | BASE | ORAL-B":"Oral-B Battery Base",
    "MANUAL+POWER | POWER | BATTERY | REFILL | ORAL-B":"Oral-B Battery Refill",
    "MANUAL+POWER | POWER | ELECTRIC | BASE | ORAL-B":"Oral-B Electric Base",
    "MANUAL+POWER | POWER | ELECTRIC | REFILL | ORAL-B":"Oral-B Electric Refill",
    "MANUAL+POWER | POWER | HYBRID | BASE | ORAL-B":"Oral-B Hybrid",
    "Oral-B Battery":"Oral-B Battery",
    "MANUAL+POWER | POWER | GLEEM":"GLEEM PTB",
    "MANUAL+POWER | MANUAL | MOON (MOON ORAL CARE LLC)":"MOON MTB",
    "CREST MTB":"CREST MTB",
    "ORAL-B ELECTRIC":"ORAL-B ELECTRIC",
    "MANUAL+POWER | MANUAL | DR FRESH":"DR FRESH MTB",
    "MANUAL+POWER | POWER | DR FRESH":"DR FRESH PTB",
    "DR FRESH TOOTHBRUSHES":"DR FRESH TOOTHBRUSHES",
    "MANUAL+POWER | MANUAL | PRVT LBL":"PRIVATE LABEL MTB",
    "PRIVATE LABEL TOOTHBRUSHES":"PRIVATE LABEL TOOTHBRUSHES",
    "MANUAL+POWER | POWER | SONICARE":"SONICARE PTB",
    "MANUAL+POWER | POWER | SMILE DIRECT CLUB":"SMILE DIRECT CLUB PTB",
    "MANUAL+POWER | MANUAL | A&H SPIN BRUSH":"A&H MTB",
    "MANUAL+POWER | POWER | A&H SPIN BRUSH":"A&H PTB",
    "A&H TOOTHBRUSHES":"A&H TOOTHBRUSHES",
    "MANUAL+POWER | POWER | PRVT LBL | ELECTRIC BASE MID TIER":"QUIP PTB",
    "MANUAL+POWER | MANUAL | REACH":"REACH MTB",
    "PRIVATE LABEL PTB":"PRIVATE LABEL PTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE 360":"Colgate 360 MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE GUM HEALTH":"Colgate Gum Health MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE SLIM SOFT":"Colgate Slim Soft MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE MX FR":"Colgate Max Fresh MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE WAVE":"Colgate Wave MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE GUM COMFORT":"Colgate Gum Comfort MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE TOTAL":"Colgate Total MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE TRIPLE ACTION":"Colgate Triple Action MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE PLUS":"Colgate Plus MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE CLASSIC CLEAN":"Colgate Classic Clean MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE EXTRA CLN":"Colgate Extra Clean MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE TRAVEL":"Colgate Travel MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE KIDS":"Colgate Kids MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE MAX WHT":"Colgate Max White MTB",
    "Colgate 360 Enamel Health MTB":"COLGATE 360 ENAMEL HEALTH MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 ENAMEL HLTH":"COLGATE 360 ENAMEL HEALTH WHITENING MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 ENAMEL HLTH WHT":"COLGATE 360 ENAMEL HEALTH SENSITIVE MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 TOTAL ADVANCED":"Colgate 360 Total Advanced MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 BASE":"Colgate 360 Base MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 OPTIC WHITE":"Colgate 360 Optic White MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 SENS PRO RELIEF":"Colgate 360 Sensitive Pro Relief MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 OPTIC WHITE PLATNM":"Colgate 360 Optic White Platinum MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 TOTAL ADV FLOSSTIP | ADULT":"Colgate 360 Flosstip MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 4 ZONE":"Colgate 360 4 Zone MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 OPTIC WHT ADVANCED":"Colgate 360 Optic White Advanced MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 ESSENTIAL CHRCOL":"Colgate 360 Charcoal MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE TOTAL WHITENING":"Colgate Total Whitening (8PK) MTB",
    "MANUAL+POWER | MANUAL | P&G | CREST | KIDS":"Crest Kids MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B CAVITY DEFENSE":"ORAL-B CAVITY DEFENSE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B HEALTHY CLEAN":"ORAL-B HEALTHY CLEAN MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B INDICATOR":"ORAL-B INDICATOR MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE":"ORAL-B 3D WHITE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B COMPLETE":"ORAL-B COMPLETE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH":"ORAL-B PRO-HEALTH MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B SENSI":"ORAL-B SENSI MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B CHARCOAL":"ORAL-B CHARCOAL MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B CLIC":"ORAL-B CLIC MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B FRESH & CLEAN":"ORAL-B FRESH & CLEAN MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B GUM CARE":"ORAL-B GUM CARE MTB",
    "ORAL-B VIVID MTB":"ORAL-B VIVID MTB",
    "COLGATE VALUE MTB":"COLGATE VALUE MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE WAVE":"Colgate Mid-Tier MTB",
    "Colgate Premium MTB":"Colgate Premium MTB",
    "Colgate 360 Premium MTB":"Colgate 360 Premium MTB",
    "Colgate 360 Super Premium MTB":"Colgate 360 Super Premium MTB",
    "Colgate Super Premium MTB":"Colgate Super Premium MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE BAMBOO":"Colgate Uber Premium MTB",
    "Oral-B Kids MTB":"ORAL-B KIDS MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH ALL IN ONE":"ORAL-B PRO HEALTH ALL IN ONE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH BASE":"ORAL-B PRO HEALTH BASE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH CLINICAL":"ORAL-B PRO HEALTH CLINICAL MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH COMPACT CLN":"ORAL-B PRO HEALTH COMPACT CLEAN MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH SUGAR DEFNSE":"ORAL-B PRO HEALTH SUGAR DEFENSE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PROADVANTAGE":"ORAL-B PROADVANTAGE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE RADIANT":"ORAL-B 3D WHITE RADIANT MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE VIVID":"ORAL-B 3D WHITE VIVID MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH VITALIZER":"ORAL-B PRO HEALTH VITALIZER MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH ADVANCED":"ORAL-B PRO HEALTH ADVANCED MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE PRO-FLEX":"SBV MAN ORAL-B 3D WHITE PRO-FLEX",
    "ORAL-B 3D WHITE PRO-FLEX MTB":"ORAL-B 3D WHITE PRO-FLEX MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE GLAMOROUS":"ORAL-B 3D WHITE GLAMOROUS MTB",
    "Oral-B Value MTB":"Oral-B Value MTB",
    "Oral-B Mid-Tier MTB":"Oral-B Mid-Tier MTB",
    "Oral-B Pro-Health Premium MTB":"Oral-B Pro-Health Premium MTB",
    "Oral-B 3D White Premium MTB":"Oral-B 3D White Premium MTB",
    "Oral-B Premium MTB":"Oral-B Premium MTB",
    "Oral-B Pro-Health Super Premium MTB":"Oral-B Pro-Health Super Premium MTB",
    "Oral-B 3D White Super Premium MTB":"Oral-B 3D White Super Premium MTB",
    "Oral-B Uber Premium MTB":"Oral-B Uber Premium MTB",
    "Oral-B Super Premium MTB":"Oral-B Super Premium MTB",
    "MANUAL+POWER | MANUAL | 1 PK":"MTB 1PK",
    "MANUAL+POWER | MANUAL | 2 PK":"MTB 2PK",
    "MANUAL+POWER | MANUAL | 3 PK":"MTB 3PK",
    "MANUAL+POWER | MANUAL | 4 PK":"MTB 4PK",
    "MANUAL+POWER | MANUAL | 5 PK":"MTB 5PK",
    "MANUAL+POWER | MANUAL | 6 PK":"MTB 6PK",
    "MANUAL+POWER | MANUAL | 7 PK":"MTB 7PK",
    "MANUAL+POWER | MANUAL | 8 PK":"MTB 8PK",
    "MANUAL+POWER | MANUAL | 10 PK":"MTB 10PK",
    "":"MTB 12PK",
    "MTB 4-5PK":"MTB 4-5PK",
    "MTB 6-7PK":"MTB 6-7PK",
    "MANUAL+POWER | MANUAL | XSFT":"MTB Extra Soft",
    "MANUAL+POWER | MANUAL | SOFT":"MTB Soft",
    "MANUAL+POWER | MANUAL | MEDIUM":"MTB Medium",
    "MANUAL+POWER | MANUAL | FIRM":"MTB Firm",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | HYBRID | COLGATE 360 POWER":"Colgate 360 Power Hybrid TB",
    "":"Colgate Max White Sonic Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | HYBRID | COLGATE KIDS":"Colgate Kids Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 SONIC PWR FLOSSTIP | HYBRID":"Colgate 360 Flosstip Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 BATTERY | COLGATE 360 BATTERY OPTIC WHT":"SBV PWR COLGATE 360 BATTERY OPTIC WHT",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 SONIC PWR OPTIC WT | HYBRID":"Colgate 360 Optic White Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 POWER | BATTERY":"Colgate 360 Power Battery TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 SONIC PWR":"Colgate 360 Sonic Battery TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE KIDS | BATTERY":"Colgate Kids Battery TB",
    "Colgate 360 Advanced Battery TB":"Colgate 360 Advanced Battery TB",
    "Colgate 360 Base Battery TB":"Colgate 360 Base Battery TB",
    "Colgate Minions Battery TB":"Colgate Minions Battery TB",
    "Colgate Teenage Mutant Ninja Turtle Battery TB":"Colgate Teenage Mutant Ninja Turtles Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS RYAN'S WORLD BTB":"Colgate Ryan's World Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS TROLLS BTB":"Colgate Trolls Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS PJ MASKS BTB":"Colgate PJ Masks Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS PEPPA PIG BTB":"Colgate Peppa Pig Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS BATMAN BTB":"Colgate Batman Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS WONDER WOMAN BTB":"Colgate Wonder Woman Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE TRANSFORMERS BTB":"Colgate Transformers Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PULSAR | HYBRID":"Oral-B Pulsar Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS | HYBRID":"Oral-B Kids Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PULSAR | ORAL-B PULSAR DEEPER CLEAN | HYBRID":"Oral-B Pulsar Deeper Clean Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PULSAR | ORAL-B PULSAR 3D WHITE | HYBRID":"Oral-B Pulsar 3D White Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B 3D WHITE BATTERY":"Oral-B 3D White Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B COMPLETE BATTERY":"Oral-B Complete Battery TB",
    "Oral-B ProAdvantage Battery TB":"Oral-B ProAdvantage Battery TB",
    "Oral-B Deep Clean Battery TB":"Oral-B Deep Clean Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B CAP":"Oral-B Cap Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS":"Oral-B Kids TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PRO-HEALTH BATTERY":"Oral-B Pro-Health Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B BATTERY BASE REM":"Oral-B Gum Care Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PROFESSIONAL CARE | ELECTRIC | BASE":"Oral-B Professional Care Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PROFESSIONAL CARE | ELECTRIC | REFILL":"Oral-B Professional Care Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS | ELECTRIC | BASE":"Oral-B Kids Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS | ELECTRIC | REFILL":"Oral-B Kids Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GUM CARE | ELECTRIC | REFILL":"Oral-B Gum Care Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GUM CARE | ELECTRIC | BASE":"Oral-B Gum Care Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PROADVANTAGE | ELECTRIC | BASE":"Oral-B ProAdvantage Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B 3D WHITE ELECTRIC | ELECTRIC | BASE":"Oral-B 3D White Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B 3D WHITE ELECTRIC | ELECTRIC | REFILL":"Oral-B 3D White Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GENIUS | ELECTRIC | BASE":"Oral-B Genius Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GENIUS X | ELECTRIC | BASE":"Oral-B Genius X Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PRO WHITE | ELECTRIC | REFILL":"Oral-B Pro White Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B VITALITY | ELECTRIC | BASE":"Oral-B Vitality Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B REFILL REM | ELECTRIC | REFILL":"Oral-B Other Refill",
    "SBR PWR SONICARE ESSENCE":"SBR PWR SONICARE ESSENCE",
    "SBR PWR SONICARE DIAMOND CLEAN":"SBR PWR SONICARE DIAMOND CLEAN",
    "":"SBR PWR SONICARE ESSENTIAL CLEAN",
    "SBR PWR SONICARE FLEXCARE":"SBR PWR SONICARE FLEXCARE",
    "SBR PWR SONICARE GUM HEALTH":"SBR PWR SONICARE GUM HEALTH",
    "SBR PWR SONICARE HLTHYWHT":"SBR PWR SONICARE HLTHYWHT",
    "SBR PWR SONICARE KIDS":"SBR PWR SONICARE KIDS",
    "SBR PWR SONICARE PLAQUE CONTROL":"SBR PWR SONICARE PLAQUE CONTROL",
    "SBR PWR A/O SONICARE BASE":"SBR PWR A/O SONICARE BASE",
    "MANUAL+POWER | POWER | SONICARE | ELECTRIC | BASE":"Sonicare Electric Base",
    "MANUAL+POWER | POWER | SONICARE | ELECTRIC | REFILL":"Sonicare Electric Refill",
    "MANUAL+POWER | POWER | SONICARE | SONICARE DIAMOND CLEAN | ELECTRIC | BASE":"Sonicare Diamond Clean Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE FLEXCARE | ELECTRIC | BASE":"Sonicare Flexcare Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE GUM HEALTH | ELECTRIC | BASE":"Sonicare Gum Health Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE HLTHYWHT | ELECTRIC | BASE":"Sonicare Healthy White Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE PLAQUE CONTROL | ELECTRIC | BASE":"Sonicare Plaque Control Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE KIDS | ELECTRIC | BASE":"Sonicare Kids Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE EASY CLEAN | ELECTRIC | BASE":"Sonicare Easy Clean Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE PROTECTIVE CLEAN | ELECTRIC | BASE":"Sonicare Protective Clean Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE ESSENCE | ELECTRIC | BASE":"Sonicare Essence Electric TB Base",
    "MANUAL+POWER | POWER | PRVT LBL | BATTERY":"Private Label Battery",
    "MANUAL+POWER | POWER | PRVT LBL | HYBRID":"Private Label Hybrid",
    "MANUAL+POWER | POWER | PRVT LBL | ELECTRIC | REFILL":"Private Label Electric Refill",
    "A&H SPINBRUSH BATTERY":"A&H SPINBRUSH BATTERY",
    "MANUAL+POWER | POWER | PRVT LBL | BATTERY BASE LOW TIER":"Private Label Electric Base",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE BAMBOO | 1 PK":"Colgate Bamboo MTB",
    "REACH PTB":"REACH PTB",
    "REACH TB":"REACH TB",
    "MANUAL+POWER | POWER | COLGATE HUM | COLGATE HUM BATTERY":"Hum Battery TB",
    "MANUAL+POWER | POWER | COLGATE HUM | COLGATE HUM RECHARGEABLE":"HUM ELECTRIC BASE",
    "MANUAL+POWER | POWER | COLGATE HUM | COLGATE HUM REFILL":"HUM ELECTRIC REFILL",
    "MANUAL+POWER | POWER | COLGATE HUM | ELECTRIC":"Hum Electric",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE RENEWAL":"Colgate Renewal MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE KEEP":"Colgate Keep MTB",
    "MANUAL+POWER | MANUAL | P&G | ORAL-B | ORAL-B CLIC | ORAL-B CLIC BASE":"Oral-B Clic Starter",
    "MANUAL+POWER | MANUAL | P&G | ORAL-B | ORAL-B CLIC | ORAL-B CLIC REFILL":"Oral-B Clic Refills",

    }

# %%
#Updating the mappings
TB_Weekly["Markets"].replace(Market_Mapping,inplace=True)
TB_Weekly["Products"].replace(Product_Mapping,inplace=True)
TB_Weekly.rename(columns = Fact_Mapping, inplace = True)

# %% [markdown]
# **Updating Time Period Nomenclature**

# %%
now=datetime.datetime.now()
delay= datetime.timedelta(days=20)
a= now - delay
year=str(a.year)[-2:]
print(year)
# Out:
# 21

# %%
name = "YTD '" + year
TB_Weekly["Periods"] = TB_Weekly["Periods"].str.replace("YTD",name)

# %%
#Changing column names
mapping = {"Markets":"MKT", "Products":"PROD", "Periods":"PER"}
TB_Weekly.rename(columns = mapping, inplace = True)

# %% [markdown]
# **Updating Fact Details**

# %%
TB_Weekly["PTB $ Share"] = TB_Weekly["MTB $ Share"]
TB_Weekly["PTB $ Share YAG Chg"] = TB_Weekly["MTB $ Share YAG Chg"]
TB_Weekly["PTB Vol Share"] = TB_Weekly["MTB Vol Share"]
TB_Weekly["PTB Vol Share YAG Chg"] = TB_Weekly["MTB Vol Share YAG Chg"]
TB_Weekly["MTB Unit Share"] = TB_Weekly["PTB Unit Share"]
TB_Weekly["MTB Unit Share YAG Chg"] = TB_Weekly["PTB Unit Share YAG Chg"] 
TB_Weekly["PTB Promo $ Share"] = TB_Weekly["MTB Promo $ Share"]
TB_Weekly["PTB Promo $ Share YAG Chg"] = TB_Weekly["MTB Promo $ Share YAG Chg"]

# %%
#Sorting the columns
final_column_sorting=['MKT', 'PROD', 'PER', "Dollars","Dollars YAG %Chg","Dollars YAG","EQ Units","Vol YAG","Vol YAG %Chg","Units","Units YAG Period","Units YAG %Chg","MTB $ Share","MTB $ Share YAG Chg","PTB $ Share","PTB $ Share YAG Chg","$ Share","$ Share YAG Chg","Vol Share","Vol Share YAG Chg","MTB Vol Share","MTB Vol Share YAG Chg","PTB Vol Share","PTB Vol Share YAG Chg","Unit Share","Unit Share YAG Chg","PTB Unit Share","PTB Unit Share YAG Chg","MTB Unit Share","MTB Unit Share YAG Chg","RASP","RASP YAG %Chg","Total Distribution Pts","Total Distribution Pts YAG Chg","Promo Dollars","MTB Promo $ Share","PTB Promo $ Share","MTB Promo $ Share YAG Chg","PTB Promo $ Share YAG Chg","Dollars w/Any Promo YAG Chg","Promo Dollars YAG"]
final = TB_Weekly[final_column_sorting]

# %%
path_TB="//falmumapp34/Nielsen Connect Transition & Maintenance (20-SCP-3650)/05. Output Data/"

# %%
#Writing file to the output folder
final.to_csv(path_TB+"OC_Weekly_Report_TB.csv",index=False)

# %% [markdown]
# ## TOOTHBRUSH LY

# %%
#Reading raw file
TB_Weekly_LY= pd.read_excel("//falmumapp34/Nielsen Connect Transition & Maintenance (20-SCP-3650)/03. Raw Data/Connect Data/OW Weekly Reports/OC Weekly Report TB_LY Data.xlsx")

# %%
#Replacing NaN values with 0
TB_Weekly_LY.fillna(value=0,inplace=True)

# %% [markdown]
# **Creating Fact, Market and Product Mapping Dictionaries to change corresponding names as required going ahead**

# %%
Fact_Mapping = {
    "$":"Dollars",
    "$ % Chg YA":"Dollars YAG %Chg",
    "$ YA":"Dollars YAG",
    "EQ":"EQ Units",
    "EQ YA":"Vol YAG",
    "EQ % Chg YA":"Vol YAG %Chg",
    "Units":"Units",
    "Units YA":"Units YAG Period",
    "Units % Chg YA":"Units YAG %Chg",
    "$ Shr - CP CATEGORY":"MTB $ Share",
    "$ Shr Chg YA - CP CATEGORY":"MTB $ Share YAG Chg",
    #"$ Shr - CP CATEGORY":"PTB $ Share",
    #"$ Shr Chg YA - CP CATEGORY":"PTB $ Share YAG Chg",
    "$ Shr - CP MANUAL AND PWR":"$ Share",
    "$ Shr Chg YA - CP MANUAL AND PWR":"$ Share YAG Chg",
    "EQ Shr - CP MANUAL AND PWR":"Vol Share",
    "EQ Shr Chg YA - CP MANUAL AND PWR":"Vol Share YAG Chg",
    "EQ Shr - CP CATEGORY":"MTB Vol Share",
    "EQ Shr Chg YA - CP CATEGORY":"MTB Vol Share YAG Chg",
    #"EQ Shr - CP CATEGORY":"PTB Vol Share",
    #"EQ Shr Chg YA - CP CATEGORY":"PTB Vol Share YAG Chg",
    "Units Shr - CP MANUAL AND PWR":"Unit Share",
    "Units Shr Chg YA - CP MANUAL AND PWR":"Unit Share YAG Chg",
    "Units Shr - CP CATEGORY":"PTB Unit Share",
    "Units Shr Chg YA - CP CATEGORY":"PTB Unit Share YAG Chg",
    #"Units Shr - CP CATEGORY":"MTB Unit Share",
    #"Units Shr Chg YA - CP CATEGORY":"MTB Unit Share YAG Chg",
    "Avg Unit Price":"RASP",
    "Avg Unit Price % Chg YA":"RASP YAG %Chg",
    "TDP":"Total Distribution Pts",
    "TDP Chg YA":"Total Distribution Pts YAG Chg",
    "Any Promo $":"Promo Dollars",
    "Any Promo $ Shr - CP CATEGORY":"MTB Promo $ Share",
    #"Any Promo $ Shr - CP CATEGORY":"PTB Promo $ Share",
    "Any Promo $ Shr Chg YA - CP CATEGORY":"MTB Promo $ Share YAG Chg",
    #"Any Promo $ Shr Chg YA - CP CATEGORY":"PTB Promo $ Share YAG Chg",
    "Any Promo $ Chg YA":"Dollars w/Any Promo YAG Chg",
    "Any Promo $ YA":"Promo Dollars YAG"
    }

# %%
Market_Mapping = {
    "Total US xAOC":"ALL OUTLET",
    "Total US Food":"FOOD",
    "Total US Drug":"DRUG",
    "MASS":"MASS",
    "Dol Gen Total TA":"DOLLAR GENERAL",
    "Family Dollar Total TA":"FAMILY DOLLAR",
    "BJs Total TA":"BJ'S",
    "Sam's Total TA":"SAM'S",
    "Walmart Total US TA":"WALMART",
    "Target Total BM/FF TA":"TARGET",
    "CVS Total Corp WO HI TA":"CVS",
    "Walgreens Corp Total TA":"WALGREENS",
    "Rite Aid - Corp Total TA":"RITE AID",
    "ShopRite Total TA":"SHOPRITE",
    "Publix Total TA":"PUBLIX",
    "Ahold USA Corp Total TA":"AHOLD",
    "Meijer Total TA":"MEIJER",
    "Wegmans Total TA":"WEGMAN'S",
    "VDC":"VDC",
    "CLUB":"CLUB",
    "ALBSCO Total Company TA":"ALBERTSONS/SAFEWAY"
    }

# %%
Product_Mapping={
    "TB Category":"TB Category",
    "MANUAL+POWER | MANUAL":"MTB Category",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE":"Colgate MTB",
    "MANUAL+POWER | POWER":"PTB Category",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE":"Colgate PTB",
    "MANUAL+POWER | POWER | HYBRID":"Hybrid TB",
    "MANUAL+POWER | POWER | BATTERY":"Battery TB",
    "MANUAL+POWER | POWER | BATTERY | BASE":"Battery Base",
    "MANUAL+POWER | POWER | BATTERY | REFILL":"Battery Refills",
    "MANUAL+POWER | POWER | ELECTRIC":"Electric TB",
    "MANUAL+POWER | POWER | ELECTRIC | BASE":"Electric Base",
    "MANUAL+POWER | POWER | ELECTRIC | REFILL":"Electric Refills",
    "CP TOOTHBRUSHES":"CP TOOTHBRUSHES",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | TOMS OF MAINE":"TOMS MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | HELLO":"HELLO MTB",
    "P&G Toothbrushes":"P&G Toothbrushes",
    "MANUAL+POWER | MANUAL | P&G":"P&G MTB",
    "MANUAL+POWER | POWER | P&G":"P&G PTB",
    "CP MTB":"CP MTB",
    "CP Battery":"Colgate Battery",
    "MANUAL+POWER | POWER | BATTERY | COLGATE-PALMOLIVE | BASE":"Colgate Battery Base",
    "MANUAL+POWER | POWER | BATTERY | COLGATE-PALMOLIVE | REFILL":"Colgate Battery Refill",
    "MANUAL+POWER | POWER | HYBRID | COLGATE-PALMOLIVE | BASE":"Colgate Hybrid",
    "MANUAL+POWER | MANUAL | ORAL-B":"ORAL-B MTB",
    "MANUAL+POWER | POWER | ORAL-B":"ORAL-B PTB",
    "ORAL-B TOOTHBRUSHES":"ORAL-B TOOTHBRUSHES",
    "MANUAL+POWER | POWER | BATTERY | BASE | ORAL-B":"Oral-B Battery Base",
    "MANUAL+POWER | POWER | BATTERY | REFILL | ORAL-B":"Oral-B Battery Refill",
    "MANUAL+POWER | POWER | ELECTRIC | BASE | ORAL-B":"Oral-B Electric Base",
    "MANUAL+POWER | POWER | ELECTRIC | REFILL | ORAL-B":"Oral-B Electric Refill",
    "MANUAL+POWER | POWER | HYBRID | BASE | ORAL-B":"Oral-B Hybrid",
    "Oral-B Battery":"Oral-B Battery",
    "MANUAL+POWER | POWER | GLEEM":"GLEEM PTB",
    "MANUAL+POWER | MANUAL | MOON (MOON ORAL CARE LLC)":"MOON MTB",
    "CREST MTB":"CREST MTB",
    "ORAL-B ELECTRIC":"ORAL-B ELECTRIC",
    "MANUAL+POWER | MANUAL | DR FRESH":"DR FRESH MTB",
    "MANUAL+POWER | POWER | DR FRESH":"DR FRESH PTB",
    "DR FRESH TOOTHBRUSHES":"DR FRESH TOOTHBRUSHES",
    "MANUAL+POWER | MANUAL | PRVT LBL":"PRIVATE LABEL MTB",
    "PRIVATE LABEL TOOTHBRUSHES":"PRIVATE LABEL TOOTHBRUSHES",
    "MANUAL+POWER | POWER | SONICARE":"SONICARE PTB",
    "MANUAL+POWER | POWER | SMILE DIRECT CLUB":"SMILE DIRECT CLUB PTB",
    "MANUAL+POWER | MANUAL | A&H SPIN BRUSH":"A&H MTB",
    "MANUAL+POWER | POWER | A&H SPIN BRUSH":"A&H PTB",
    "A&H TOOTHBRUSHES":"A&H TOOTHBRUSHES",
    "MANUAL+POWER | POWER | PRVT LBL | ELECTRIC BASE MID TIER":"QUIP PTB",
    "MANUAL+POWER | MANUAL | REACH":"REACH MTB",
    "PRIVATE LABEL PTB":"PRIVATE LABEL PTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE 360":"Colgate 360 MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE GUM HEALTH":"Colgate Gum Health MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE SLIM SOFT":"Colgate Slim Soft MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE MX FR":"Colgate Max Fresh MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE WAVE":"Colgate Wave MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE GUM COMFORT":"Colgate Gum Comfort MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE TOTAL":"Colgate Total MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE TRIPLE ACTION":"Colgate Triple Action MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE PLUS":"Colgate Plus MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE CLASSIC CLEAN":"Colgate Classic Clean MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE EXTRA CLN":"Colgate Extra Clean MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE TRAVEL":"Colgate Travel MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE KIDS":"Colgate Kids MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE MAX WHT":"Colgate Max White MTB",
    "Colgate 360 Enamel Health MTB":"COLGATE 360 ENAMEL HEALTH MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 ENAMEL HLTH":"COLGATE 360 ENAMEL HEALTH WHITENING MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 ENAMEL HLTH WHT":"COLGATE 360 ENAMEL HEALTH SENSITIVE MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 TOTAL ADVANCED":"Colgate 360 Total Advanced MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 BASE":"Colgate 360 Base MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 OPTIC WHITE":"Colgate 360 Optic White MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 SENS PRO RELIEF":"Colgate 360 Sensitive Pro Relief MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 OPTIC WHITE PLATNM":"Colgate 360 Optic White Platinum MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 TOTAL ADV FLOSSTIP | ADULT":"Colgate 360 Flosstip MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 4 ZONE":"Colgate 360 4 Zone MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 OPTIC WHT ADVANCED":"Colgate 360 Optic White Advanced MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 | COLGATE 360 ESSENTIAL CHRCOL":"Colgate 360 Charcoal MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE TOTAL WHITENING":"Colgate Total Whitening (8PK) MTB",
    "MANUAL+POWER | MANUAL | P&G | CREST | KIDS":"Crest Kids MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B CAVITY DEFENSE":"ORAL-B CAVITY DEFENSE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B HEALTHY CLEAN":"ORAL-B HEALTHY CLEAN MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B INDICATOR":"ORAL-B INDICATOR MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE":"ORAL-B 3D WHITE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B COMPLETE":"ORAL-B COMPLETE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH":"ORAL-B PRO-HEALTH MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B SENSI":"ORAL-B SENSI MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B CHARCOAL":"ORAL-B CHARCOAL MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B CLIC":"ORAL-B CLIC MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B FRESH & CLEAN":"ORAL-B FRESH & CLEAN MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B GUM CARE":"ORAL-B GUM CARE MTB",
    "ORAL-B VIVID MTB":"ORAL-B VIVID MTB",
    "COLGATE VALUE MTB":"COLGATE VALUE MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE WAVE":"Colgate Mid-Tier MTB",
    "Colgate Premium MTB":"Colgate Premium MTB",
    "Colgate 360 Premium MTB":"Colgate 360 Premium MTB",
    "Colgate 360 Super Premium MTB":"Colgate 360 Super Premium MTB",
    "Colgate Super Premium MTB":"Colgate Super Premium MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE BAMBOO":"Colgate Uber Premium MTB",
    "Oral-B Kids MTB":"ORAL-B KIDS MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH ALL IN ONE":"ORAL-B PRO HEALTH ALL IN ONE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH BASE":"ORAL-B PRO HEALTH BASE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH CLINICAL":"ORAL-B PRO HEALTH CLINICAL MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH COMPACT CLN":"ORAL-B PRO HEALTH COMPACT CLEAN MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH SUGAR DEFNSE":"ORAL-B PRO HEALTH SUGAR DEFENSE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PROADVANTAGE":"ORAL-B PROADVANTAGE MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE RADIANT":"ORAL-B 3D WHITE RADIANT MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE VIVID":"ORAL-B 3D WHITE VIVID MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH VITALIZER":"ORAL-B PRO HEALTH VITALIZER MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B PRO-HEALTH ADVANCED":"ORAL-B PRO HEALTH ADVANCED MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE PRO-FLEX":"SBV MAN ORAL-B 3D WHITE PRO-FLEX",
    "ORAL-B 3D WHITE PRO-FLEX MTB":"ORAL-B 3D WHITE PRO-FLEX MTB",
    "MANUAL+POWER | MANUAL | ORAL-B | ORAL-B 3D WHITE GLAMOROUS":"ORAL-B 3D WHITE GLAMOROUS MTB",
    "Oral-B Value MTB":"Oral-B Value MTB",
    "Oral-B Mid-Tier MTB":"Oral-B Mid-Tier MTB",
    "Oral-B Pro-Health Premium MTB":"Oral-B Pro-Health Premium MTB",
    "Oral-B 3D White Premium MTB":"Oral-B 3D White Premium MTB",
    "Oral-B Premium MTB":"Oral-B Premium MTB",
    "Oral-B Pro-Health Super Premium MTB":"Oral-B Pro-Health Super Premium MTB",
    "Oral-B 3D White Super Premium MTB":"Oral-B 3D White Super Premium MTB",
    "Oral-B Uber Premium MTB":"Oral-B Uber Premium MTB",
    "Oral-B Super Premium MTB":"Oral-B Super Premium MTB",
    "MANUAL+POWER | MANUAL | 1 PK":"MTB 1PK",
    "MANUAL+POWER | MANUAL | 2 PK":"MTB 2PK",
    "MANUAL+POWER | MANUAL | 3 PK":"MTB 3PK",
    "MANUAL+POWER | MANUAL | 4 PK":"MTB 4PK",
    "MANUAL+POWER | MANUAL | 5 PK":"MTB 5PK",
    "MANUAL+POWER | MANUAL | 6 PK":"MTB 6PK",
    "MANUAL+POWER | MANUAL | 7 PK":"MTB 7PK",
    "MANUAL+POWER | MANUAL | 8 PK":"MTB 8PK",
    "MANUAL+POWER | MANUAL | 10 PK":"MTB 10PK",
    "":"MTB 12PK",
    "MTB 4-5PK":"MTB 4-5PK",
    "MTB 6-7PK":"MTB 6-7PK",
    "MANUAL+POWER | MANUAL | XSFT":"MTB Extra Soft",
    "MANUAL+POWER | MANUAL | SOFT":"MTB Soft",
    "MANUAL+POWER | MANUAL | MEDIUM":"MTB Medium",
    "MANUAL+POWER | MANUAL | FIRM":"MTB Firm",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | HYBRID | COLGATE 360 POWER":"Colgate 360 Power Hybrid TB",
    "":"Colgate Max White Sonic Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | HYBRID | COLGATE KIDS":"Colgate Kids Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 SONIC PWR FLOSSTIP | HYBRID":"Colgate 360 Flosstip Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 BATTERY | COLGATE 360 BATTERY OPTIC WHT":"SBV PWR COLGATE 360 BATTERY OPTIC WHT",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 SONIC PWR OPTIC WT | HYBRID":"Colgate 360 Optic White Hybrid TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 POWER | BATTERY":"Colgate 360 Power Battery TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE 360 SONIC PWR":"Colgate 360 Sonic Battery TB",
    "MANUAL+POWER | POWER | COLGATE-PALMOLIVE | COLGATE | COLGATE KIDS | BATTERY":"Colgate Kids Battery TB",
    "Colgate 360 Advanced Battery TB":"Colgate 360 Advanced Battery TB",
    "Colgate 360 Base Battery TB":"Colgate 360 Base Battery TB",
    "Colgate Minions Battery TB":"Colgate Minions Battery TB",
    "Colgate Teenage Mutant Ninja Turtle Battery TB":"Colgate Teenage Mutant Ninja Turtles Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS RYAN'S WORLD BTB":"Colgate Ryan's World Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS TROLLS BTB":"Colgate Trolls Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS PJ MASKS BTB":"Colgate PJ Masks Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS PEPPA PIG BTB":"Colgate Peppa Pig Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS BATMAN BTB":"Colgate Batman Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE KIDS WONDER WOMAN BTB":"Colgate Wonder Woman Battery TB",
    "MANUAL+POWER | POWER | COLGATE KIDS | COLGATE TRANSFORMERS BTB":"Colgate Transformers Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PULSAR | HYBRID":"Oral-B Pulsar Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS | HYBRID":"Oral-B Kids Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PULSAR | ORAL-B PULSAR DEEPER CLEAN | HYBRID":"Oral-B Pulsar Deeper Clean Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PULSAR | ORAL-B PULSAR 3D WHITE | HYBRID":"Oral-B Pulsar 3D White Hybrid TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B 3D WHITE BATTERY":"Oral-B 3D White Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B COMPLETE BATTERY":"Oral-B Complete Battery TB",
    "Oral-B ProAdvantage Battery TB":"Oral-B ProAdvantage Battery TB",
    "Oral-B Deep Clean Battery TB":"Oral-B Deep Clean Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B CAP":"Oral-B Cap Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS":"Oral-B Kids TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PRO-HEALTH BATTERY":"Oral-B Pro-Health Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B BATTERY BASE REM":"Oral-B Gum Care Battery TB",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PROFESSIONAL CARE | ELECTRIC | BASE":"Oral-B Professional Care Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PROFESSIONAL CARE | ELECTRIC | REFILL":"Oral-B Professional Care Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS | ELECTRIC | BASE":"Oral-B Kids Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B KIDS | ELECTRIC | REFILL":"Oral-B Kids Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GUM CARE | ELECTRIC | REFILL":"Oral-B Gum Care Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GUM CARE | ELECTRIC | BASE":"Oral-B Gum Care Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PROADVANTAGE | ELECTRIC | BASE":"Oral-B ProAdvantage Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B 3D WHITE ELECTRIC | ELECTRIC | BASE":"Oral-B 3D White Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B 3D WHITE ELECTRIC | ELECTRIC | REFILL":"Oral-B 3D White Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GENIUS | ELECTRIC | BASE":"Oral-B Genius Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B GENIUS X | ELECTRIC | BASE":"Oral-B Genius X Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B PRO WHITE | ELECTRIC | REFILL":"Oral-B Pro White Electric TB Refill",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B VITALITY | ELECTRIC | BASE":"Oral-B Vitality Electric TB Base",
    "MANUAL+POWER | POWER | P&G | ORAL-B | ORAL-B REFILL REM | ELECTRIC | REFILL":"Oral-B Other Refill",
    "SBR PWR SONICARE ESSENCE":"SBR PWR SONICARE ESSENCE",
    "SBR PWR SONICARE DIAMOND CLEAN":"SBR PWR SONICARE DIAMOND CLEAN",
    "":"SBR PWR SONICARE ESSENTIAL CLEAN",
    "SBR PWR SONICARE FLEXCARE":"SBR PWR SONICARE FLEXCARE",
    "SBR PWR SONICARE GUM HEALTH":"SBR PWR SONICARE GUM HEALTH",
    "SBR PWR SONICARE HLTHYWHT":"SBR PWR SONICARE HLTHYWHT",
    "SBR PWR SONICARE KIDS":"SBR PWR SONICARE KIDS",
    "SBR PWR SONICARE PLAQUE CONTROL":"SBR PWR SONICARE PLAQUE CONTROL",
    "SBR PWR A/O SONICARE BASE":"SBR PWR A/O SONICARE BASE",
    "MANUAL+POWER | POWER | SONICARE | ELECTRIC | BASE":"Sonicare Electric Base",
    "MANUAL+POWER | POWER | SONICARE | ELECTRIC | REFILL":"Sonicare Electric Refill",
    "MANUAL+POWER | POWER | SONICARE | SONICARE DIAMOND CLEAN | ELECTRIC | BASE":"Sonicare Diamond Clean Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE FLEXCARE | ELECTRIC | BASE":"Sonicare Flexcare Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE GUM HEALTH | ELECTRIC | BASE":"Sonicare Gum Health Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE HLTHYWHT | ELECTRIC | BASE":"Sonicare Healthy White Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE PLAQUE CONTROL | ELECTRIC | BASE":"Sonicare Plaque Control Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE KIDS | ELECTRIC | BASE":"Sonicare Kids Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE EASY CLEAN | ELECTRIC | BASE":"Sonicare Easy Clean Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE PROTECTIVE CLEAN | ELECTRIC | BASE":"Sonicare Protective Clean Electric TB Base",
    "MANUAL+POWER | POWER | SONICARE | SONICARE ESSENCE | ELECTRIC | BASE":"Sonicare Essence Electric TB Base",
    "MANUAL+POWER | POWER | PRVT LBL | BATTERY":"Private Label Battery",
    "MANUAL+POWER | POWER | PRVT LBL | HYBRID":"Private Label Hybrid",
    "MANUAL+POWER | POWER | PRVT LBL | ELECTRIC | REFILL":"Private Label Electric Refill",
    "A&H SPINBRUSH BATTERY":"A&H SPINBRUSH BATTERY",
    "MANUAL+POWER | POWER | PRVT LBL | BATTERY BASE LOW TIER":"Private Label Electric Base",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE BAMBOO | 1 PK":"Colgate Bamboo MTB",
    "REACH PTB":"REACH PTB",
    "REACH TB":"REACH TB",
    "MANUAL+POWER | POWER | COLGATE HUM | COLGATE HUM BATTERY":"Hum Battery TB",
    "MANUAL+POWER | POWER | COLGATE HUM | COLGATE HUM RECHARGEABLE":"HUM ELECTRIC BASE",
    "MANUAL+POWER | POWER | COLGATE HUM | COLGATE HUM REFILL":"HUM ELECTRIC REFILL",
    "MANUAL+POWER | POWER | COLGATE HUM | ELECTRIC":"Hum Electric",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE RENEWAL":"Colgate Renewal MTB",
    "MANUAL+POWER | MANUAL | COLGATE-PALMOLIVE | COLGATE | COLGATE KEEP":"Colgate Keep MTB",
    "MANUAL+POWER | MANUAL | P&G | ORAL-B | ORAL-B CLIC | ORAL-B CLIC BASE":"Oral-B Clic Starter",
    "MANUAL+POWER | MANUAL | P&G | ORAL-B | ORAL-B CLIC | ORAL-B CLIC REFILL":"Oral-B Clic Refills",

    }

# %%
#Updating the mappings
TB_Weekly_LY["Markets"].replace(Market_Mapping,inplace=True)
TB_Weekly_LY["Products"].replace(Product_Mapping,inplace=True)
TB_Weekly_LY.rename(columns = Fact_Mapping, inplace = True)

# %% [markdown]
# **Updating Fact Details**

# %%
TB_Weekly_LY["PTB $ Share"] = TB_Weekly_LY["MTB $ Share"]
TB_Weekly_LY["PTB $ Share YAG Chg"] = TB_Weekly_LY["MTB $ Share YAG Chg"]
TB_Weekly_LY["PTB Vol Share"] = TB_Weekly_LY["MTB Vol Share"]
TB_Weekly_LY["PTB Vol Share YAG Chg"] = TB_Weekly_LY["MTB Vol Share YAG Chg"]
TB_Weekly_LY["MTB Unit Share"] = TB_Weekly_LY["PTB Unit Share"]
TB_Weekly_LY["MTB Unit Share YAG Chg"] = TB_Weekly_LY["PTB Unit Share YAG Chg"] 
TB_Weekly_LY["PTB Promo $ Share"] = TB_Weekly_LY["MTB Promo $ Share"]
TB_Weekly_LY["PTB Promo $ Share YAG Chg"] = TB_Weekly_LY["MTB Promo $ Share YAG Chg"]

# %%
#Changing column names
mapping = {"Markets":"MKT", "Products":"PROD", "Periods":"PER"}
TB_Weekly_LY.rename(columns = mapping, inplace = True)

# %%
#Sorting the columns
final_column_sorting=['MKT', 'PROD', 'PER', "Dollars","Dollars YAG %Chg","Dollars YAG","EQ Units","Vol YAG","Vol YAG %Chg","Units","Units YAG Period","Units YAG %Chg","MTB $ Share","MTB $ Share YAG Chg","PTB $ Share","PTB $ Share YAG Chg","$ Share","$ Share YAG Chg","Vol Share","Vol Share YAG Chg","MTB Vol Share","MTB Vol Share YAG Chg","PTB Vol Share","PTB Vol Share YAG Chg","Unit Share","Unit Share YAG Chg","PTB Unit Share","PTB Unit Share YAG Chg","MTB Unit Share","MTB Unit Share YAG Chg","RASP","RASP YAG %Chg","Total Distribution Pts","Total Distribution Pts YAG Chg","Promo Dollars","MTB Promo $ Share","PTB Promo $ Share","MTB Promo $ Share YAG Chg","PTB Promo $ Share YAG Chg","Dollars w/Any Promo YAG Chg","Promo Dollars YAG"]
final = TB_Weekly_LY[final_column_sorting]

# %%
path_TB="//falmumapp34/Nielsen Connect Transition & Maintenance (20-SCP-3650)/05. Output Data/"

# %%
#Writing file to the output folder
final.to_csv(path_TB+"OC_Weekly_Report_TB_LY_Data.csv",index=False)
